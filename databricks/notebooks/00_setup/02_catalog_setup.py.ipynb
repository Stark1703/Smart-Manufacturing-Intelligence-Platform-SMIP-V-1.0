# %%
# """
# Creates the Unity Catalog for SMIP V2.

# Author:
# Sumanth Vempalle

# Version:
# 2.0.0
# """

# CATALOG = "smip_v2"

# spark.sql(f"""
# CREATE CATALOG IF NOT EXISTS {CATALOG}
# """)

# print(f"Catalog '{CATALOG}' is ready.")
