-- %% [markdown]
-- # Smart Manufacturing Intelligence Platform (SMIP)
--
--
-- ### Environment Setup
--
-- ---
--
-- ### Objective
--
-- Validate the Databricks environment before building the Manufacturing Lakehouse.
--
-- This notebook verifies:
--
-- - Spark Session
-- - Unity Catalog
-- - Catalog
-- - Schemas
-- - Volumes
-- - Runtime
-- - Workspace configuration
--
-- ---
--
-- Author
--
-- Sumanth Vempalle
--
-- Version
--
-- 1.0.0

-- %%
%python
# COMMAND ----------

from pyspark.sql import SparkSession

spark = SparkSession.builder.getOrCreate()

print("=" * 60)
print("Smart Manufacturing Intelligence Platform")
print("Environment Setup")
print("=" * 60)

-- %% [markdown]
-- ### Runtime Information

-- %%
%python
# COMMAND ----------

print("=" * 60)
print("Runtime Information")
print("=" * 60)

print(f"Spark Version : {spark.version}")

try:
    print(f"Application   : {spark.sparkContext.appName}")
    print(f"Master        : {spark.sparkContext.master}")
except Exception:
    print("Application   : Serverless Compute")
    print("Master        : Managed by Databricks")

print("=" * 60)

-- %% [markdown]
-- ### Current Catalog

-- %%
%python
# COMMAND ----------

current_catalog = spark.sql(
    "SELECT current_catalog()"
).first()[0]

print(f"Current Catalog : {current_catalog}")

-- %% [markdown]
-- ### Available Catalogs

-- %%
%python
# COMMAND ----------

display(
    spark.sql("SHOW CATALOGS")
)

-- %% [markdown]
-- ### Switch to SMIP

-- %%
%python
# COMMAND ----------

spark.sql("USE CATALOG smip")

print("Using catalog: smip")

-- %% [markdown]
-- ### Available Schemas

-- %%
%python
# COMMAND ----------

display(
    spark.sql("SHOW SCHEMAS")
)

-- %% [markdown]
-- ### Volumes

-- %%
%python
# COMMAND ----------

display(
    spark.sql(
        "SHOW VOLUMES IN smip.bronze"
    )
)

-- %% [markdown]
-- ### Summary

-- %%
%python
# COMMAND ----------

print("=" * 60)

print("Environment Validation Completed")

print("=" * 60)
