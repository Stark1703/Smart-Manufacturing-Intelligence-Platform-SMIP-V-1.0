# %%
# """
# Validate SMIP V2 environment.

# Author:
# Sumanth Vempalle

# Version:
# 2.0.0
# """

# CATALOG = "smip_v2"

# print("=" * 60)

# print("Current Catalog")

# spark.sql(f"USE CATALOG {CATALOG}")

# display(
#     spark.sql("SHOW SCHEMAS")
# )

# print("=" * 60)

# print("Bronze Volumes")

# display(
#     spark.sql("""
#     SHOW VOLUMES IN bronze
#     """)
# )

# print("=" * 60)
