# %%
# """
# Creates Unity Catalog Volumes.

# Author:
# Sumanth Vempalle

# Version:
# 2.0.0
# """

# CATALOG = "smip_v2"

# spark.sql(f"USE CATALOG {CATALOG}")

# spark.sql("""
# CREATE VOLUME IF NOT EXISTS bronze.raw
# """)

# spark.sql("""
# CREATE VOLUME IF NOT EXISTS bronze.checkpoints
# """)

# print("Volumes created successfully.")
